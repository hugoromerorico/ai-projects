# %%
# %pip install presidio-analyzer presidio-anonymizer

# %%
from presidio_analyzer import AnalyzerEngine
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig

# Initialize the Presidio analyzer and anonymizer engines
analyzer = AnalyzerEngine()
anonymizer = AnonymizerEngine()

# Example text containing PII 
text_to_analyze = (
    "My name is John Doe and my credit card number is 1234-5678-9101-1121. "
    "Feel free to contact me at john.doe@example.com or call 555-123-4567."
)

# Analyze the text for PII entities
results = analyzer.analyze(
    text=text_to_analyze,
    language='en'
    # Removed all_fields=True as it's not a valid parameter
)

# Print detection results
for result in results:
    print(f"Detected entity: {result.entity_type}, Score: {result.score}, Position: {result.start}-{result.end}")

# Anonymize the detected PII entities in the text
anonymized_result = anonymizer.anonymize(
    text=text_to_analyze,
    analyzer_results=results,
    operators={
        "DEFAULT": OperatorConfig("mask", {"masking_char": "*", "chars_to_mask": 0, "masking_length": 4})
    }
)

# Output the anonymized text
print("\nAnonymized text:")
print(anonymized_result.text)
# Out:
# Detected entity: EMAIL_ADDRESS, Score: 1.0, Position: 97-117
# Detected entity: PERSON, Score: 0.85, Position: 11-19
# Detected entity: URL, Score: 0.5, Position: 97-104
# Detected entity: URL, Score: 0.5, Position: 106-117
# Detected entity: PHONE_NUMBER, Score: 0.4, Position: 126-138
# Detected entity: IN_PAN, Score: 0.05, Position: 49-59
# ---------------------------------------------------------------------------
# InvalidParamError                         Traceback (most recent call last)
# Cell In[4], line 27
#      24     print(f"Detected entity: {result.entity_type}, Score: {result.score}, Position: {result.start}-{result.end}")
#      26 # Anonymize the detected PII entities in the text
# ---> 27 anonymized_result = anonymizer.anonymize(
#      28     text=text_to_analyze,
#      29     analyzer_results=results,
#      30     operators={
#      31         "DEFAULT": OperatorConfig("mask", {"masking_char": "*", "chars_to_mask": 0, "masking_length": 4})
#      32     }
#      33 )
#      35 # Output the anonymized text
#      36 print("\nAnonymized text:")
#
# File ~/anaconda3/envs/presidio_testing/lib/python3.12/site-packages/presidio_anonymizer/anonymizer_engine.py:96, in AnonymizerEngine.anonymize(self, text, analyzer_results, operators, conflict_resolution)
#      90 merged_results = self._merge_entities_with_whitespace_between(
#      91     text, analyzer_results
#      92 )
#      94 operators = self.__check_or_add_default_operator(operators)
# ---> 96 return self._operate(
#      97     text=text,
#      98     pii_entities=merged_results,
#      99     operators_metadata=operators,
#     100     operator_type=OperatorType.Anonymize,
#     101 )
#
# File ~/anaconda3/envs/presidio_testing/lib/python3.12/site-packages/presidio_anonymizer/core/engine_base.py:54, in EngineBase._operate(self, text, pii_entities, operators_metadata, operator_type, **operator_kwargs)
#      50 self.logger.debug(f"performing operation {entity}")
#      51 operator_metadata = self.__get_entity_operator_metadata(
#      52     entity.entity_type, operators_metadata
#      53 )
# ---> 54 changed_text = self.__operate_on_text(
#      55     entity, text_to_operate_on, operator_metadata, operator_type
#      56 )
#      57 index_from_end = text_replace_builder.replace_text_get_insertion_index(
#      58     changed_text, entity.start, entity.end
#      59 )
#      61 # The following creates an intermediate list of result entities,
#      62 # ordered from end to start, and the indexes will be normalized
#      63 # from start to end once the loop ends and the text length is deterministic.
#
# File ~/anaconda3/envs/presidio_testing/lib/python3.12/site-packages/presidio_anonymizer/core/engine_base.py:93, in EngineBase.__operate_on_text(self, text_metadata, text_to_operate_on, operator_metadata, operator_type)
#      90 params = operator_metadata.params
#      91 params["entity_type"] = entity_type
# ---> 93 operator.validate(params=params)
#      95 self.logger.debug(f"operating on {entity_type} with {operator}")
#      96 operated_on_text = operator.operate(params=params, text=text_to_operate_on)
#
# File ~/anaconda3/envs/presidio_testing/lib/python3.12/site-packages/presidio_anonymizer/operators/mask.py:54, in Mask.validate(self, params)
#      49     raise InvalidParamError(
#      50         f"Invalid input, {self.MASKING_CHAR} must be a character"
#      51     )
#      53 validate_parameter(params.get(self.CHARS_TO_MASK), self.CHARS_TO_MASK, int)
# ---> 54 validate_parameter(params.get(self.FROM_END), self.FROM_END, bool)
#
# File ~/anaconda3/envs/presidio_testing/lib/python3.12/site-packages/presidio_anonymizer/services/validators.py:54, in validate_parameter(parameter_value, parameter_name, parameter_type)
#      47 """Validate an anonymizer parameter.
#      48
#      49 Both validate the existence of an anonymizer parameter and that it is an
#      50 instance of the parameter_type. Otherwise, raise the appropriate
#      51 InvalidParamException with the parameter_name as content.
#      52 """
#      53 if parameter_value is None:
# ---> 54     raise InvalidParamError(f"Expected parameter {parameter_name}")
#      55 validate_type(parameter_value, parameter_name, parameter_type)
#
# InvalidParamError: Expected parameter from_end

# %%
from presidio_analyzer import AnalyzerEngine
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig

# Initialize the Presidio analyzer and anonymizer engines
analyzer = AnalyzerEngine()
anonymizer = AnonymizerEngine()

# Example text containing PII 
text_to_analyze = (
    "La clienta necesita ayuda para configurar Amazon Prime, pero no puede acceder a la promoción porque no recuerda su contraseña y no sabe cómo hacerlo. Aunque menciona la configuración en el móvil, el problema principal radica en el acceso a la promoción debido a las credenciales. La descripción de la categoría 'Problemas de accesos y credenciales' menciona explícitamente 'problemas con su cuenta, credenciales, claves, contraseñas o datos de acceso', lo que se ajusta perfectamente a la situación de Rosario. "
    # "Feel free to contact me at john.doe@example.com or call 555-123-4567."
)

# Analyze the text for PII entities
results = analyzer.analyze(
    text=text_to_analyze,
    language='en'
)

# Print detection results
for result in results:
    print(f"Detected entity: {result.entity_type}, Score: {result.score}, Position: {result.start}-{result.end}")

# Anonymize the detected PII entities in the text
anonymized_result = anonymizer.anonymize(
    text=text_to_analyze,
    analyzer_results=results,
    operators={
        "PERSON": OperatorConfig("replace", {"new_value": "<PERSON>"}),
        "EMAIL_ADDRESS": OperatorConfig("replace", {"new_value": "<EMAIL>"}),
        "PHONE_NUMBER": OperatorConfig("replace", {"new_value": "<PHONE>"}),
        "CREDIT_CARD": OperatorConfig("replace", {"new_value": "<CREDIT_CARD>"}),
    }
)

# Output the anonymized text
print("\nAnonymized text:")
print(anonymized_result.text)
# Out:
# Detected entity: LOCATION, Score: 0.85, Position: 0-2
# Detected entity: LOCATION, Score: 0.85, Position: 80-82
# Detected entity: PERSON, Score: 0.85, Position: 150-194
# Detected entity: LOCATION, Score: 0.85, Position: 240-242
# Detected entity: LOCATION, Score: 0.85, Position: 262-265
# Detected entity: PERSON, Score: 0.85, Position: 280-312
# Detected entity: PERSON, Score: 0.85, Position: 453-469
#
# Anonymized text:
# <LOCATION> clienta necesita ayuda para configurar Amazon Prime, pero no puede acceder a <LOCATION> promoción porque no recuerda su contraseña y no sabe cómo hacerlo. <PERSON>, el problema principal radica en el acceso a <LOCATION> promoción debido a <LOCATION> credenciales. <PERSON>Problemas de accesos y credenciales' menciona explícitamente 'problemas con su cuenta, credenciales, claves, contraseñas o datos de acceso', <PERSON> perfectamente a la situación de Rosario.

# %%
from presidio_analyzer import AnalyzerEngine, RecognizerRegistry
from presidio_analyzer.nlp_engine import NlpEngineProvider

# Create configuration containing engine name and models
configuration = {
    "nlp_engine_name": "spacy",
    "models": [
        {"lang_code": "es", "model_name": "es_core_news_md"},  # Spanish model
    ],
}

# Create NLP engine based on configuration
provider = NlpEngineProvider(nlp_configuration=configuration)
nlp_engine_spanish = provider.create_engine()

# Initialize the registry with Spanish-specific recognizers
registry = RecognizerRegistry()

# Create analyzer with Spanish configuration
analyzer = AnalyzerEngine(
    nlp_engine=nlp_engine_spanish,
    supported_languages=["es"]
)

# Example text in Spanish
# Example text in Spanish
text_to_analyze = (
    "Buenos días, soy María del servicio al cliente. ¿En qué puedo ayudarle? "
    "Hola, me llamo Antonio García Pérez. Necesito ayuda con mi cuenta. "
    "Por supuesto, ¿me puede dar su DNI? "
    "Sí, es 45678912K. "
    "¿Y su número de teléfono? "
    "Mi móvil es 666-555-444. "
    "Gracias. ¿Y su dirección actual? "
    "Vivo en Calle Mayor 123, Madrid, código postal 28001. "
    "¿Y su correo electrónico? "
    "Es antonio.garcia@gmail.com. "
    "Perfecto, ya puedo ver su cuenta en el sistema."
)

# Analyze the text with Spanish language setting
results = analyzer.analyze(
    text=text_to_analyze,
    language="es"
)

# Print detection results
for result in results:
    print(f"Detected entity: {result.entity_type}, Score: {result.score}, Position: {result.start}-{result.end}")

# Initialize anonymizer
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig

anonymizer = AnonymizerEngine()

# Anonymize the detected PII entities
anonymized_result = anonymizer.anonymize(
    text=text_to_analyze,
    analyzer_results=results,
    operators={
        "PERSON": OperatorConfig("replace", {"new_value": "<PERSONA>"}),
        "EMAIL_ADDRESS": OperatorConfig("replace", {"new_value": "<EMAIL>"}),
        "PHONE_NUMBER": OperatorConfig("replace", {"new_value": "<TELÉFONO>"}),
        "DEFAULT": OperatorConfig("replace", {"new_value": "<PII>"})
    }
)

# Output the anonymized text
print("\nAnonymized text:")
print(anonymized_result.text)
# Out:
# Detected entity: PERSON, Score: 0.85, Position: 1333-1347
# Detected entity: LOCATION, Score: 0.85, Position: 1389-1393
# Detected entity: PERSON, Score: 0.85, Position: 1449-1456
# Detected entity: PERSON, Score: 0.85, Position: 1492-1499
# Detected entity: PERSON, Score: 0.85, Position: 1936-1943
# Detected entity: LOCATION, Score: 0.85, Position: 2025-2032
# Detected entity: PERSON, Score: 0.85, Position: 2034-2047
# Detected entity: LOCATION, Score: 0.85, Position: 2050-2057
# Detected entity: PERSON, Score: 0.85, Position: 2125-2135
# Detected entity: LOCATION, Score: 0.85, Position: 2254-2261
# Detected entity: LOCATION, Score: 0.85, Position: 2263-2272
# Detected entity: LOCATION, Score: 0.85, Position: 2310-2317
# Detected entity: LOCATION, Score: 0.85, Position: 2354-2361
# Detected entity: LOCATION, Score: 0.85, Position: 2797-2808
# Detected entity: LOCATION, Score: 0.85, Position: 2818-2825
# Detected entity: LOCATION, Score: 0.85, Position: 2827-2836
# Detected entity: PERSON, Score: 0.85, Position: 3024-3028
# Detected entity: LOCATION, Score: 0.85, Position: 3054-3061
# Detected entity: PERSON, Score: 0.85, Position: 3241-3247
# Detected entity: PERSON, Score: 0.85, Position: 3367-3372
# Detected entity: PERSON, Score: 0.85, Position: 3707-3714
# Detected entity: PERSON, Score: 0.85, Position: 4082-4087
# Detected entity: PERSON, Score: 0.85, Position: 4111-4126
# Detected entity: LOCATION, Score: 0.85, Position: 4221-4229
# Detected entity: PERSON, Score: 0.85, Position: 4871-4876
# Detected entity: PERSON, Score: 0.85, Position: 4951-4963
# Detected entity: LOCATION, Score: 0.85, Position: 5010-5014
# Detected entity: PERSON, Score: 0.85, Position: 5069-5076
# Detected entity: PERSON, Score: 0.85, Position: 5118-5125
# Detected entity: PERSON, Score: 0.85, Position: 5307-5313
# Detected entity: PERSON, Score: 0.85, Position: 5381-5402
# Detected entity: PERSON, Score: 0.85, Position: 5449-5451
# Detected entity: LOCATION, Score: 0.85, Position: 5911-5921
# Detected entity: LOCATION, Score: 0.85, Position: 5924-5934
# Detected entity: LOCATION, Score: 0.85, Position: 5937-5947
# Detected entity: LOCATION, Score: 0.85, Position: 5950-5960
# Detected entity: LOCATION, Score: 0.85, Position: 5963-5973
# Detected entity: LOCATION, Score: 0.85, Position: 5976-5986
# Detected entity: LOCATION, Score: 0.85, Position: 5989-5999
# Detected entity: LOCATION, Score: 0.85, Position: 6002-6012
# Detected entity: LOCATION, Score: 0.85, Position: 6015-6025
# Detected entity: LOCATION, Score: 0.85, Position: 6028-6038
# Detected entity: LOCATION, Score: 0.85, Position: 6041-6051
# Detected entity: LOCATION, Score: 0.85, Position: 6054-6064
# Detected entity: LOCATION, Score: 0.85, Position: 6067-6077
# Detected entity: LOCATION, Score: 0.85, Position: 6080-6090
# Detected entity: LOCATION, Score: 0.85, Position: 6093-6103
# Detected entity: LOCATION, Score: 0.85, Position: 6106-6116
# Detected entity: LOCATION, Score: 0.85, Position: 6119-6129
# Detected entity: LOCATION, Score: 0.85, Position: 6132-6142
# Detected entity: LOCATION, Score: 0.85, Position: 6145-6155
# Detected entity: LOCATION, Score: 0.85, Position: 6158-6168
# Detected entity: LOCATION, Score: 0.85, Position: 6171-6181
# Detected entity: LOCATION, Score: 0.85, Position: 6184-6194
# Detected entity: LOCATION, Score: 0.85, Position: 6197-6207
# Detected entity: LOCATION, Score: 0.85, Position: 6210-6220
# Detected entity: LOCATION, Score: 0.85, Position: 6223-6233
# Detected entity: LOCATION, Score: 0.85, Position: 6236-6246
# Detected entity: LOCATION, Score: 0.85, Position: 6249-6259
# Detected entity: LOCATION, Score: 0.85, Position: 6262-6272
# Detected entity: LOCATION, Score: 0.85, Position: 6275-6285
# Detected entity: LOCATION, Score: 0.85, Position: 6288-6298
# Detected entity: LOCATION, Score: 0.85, Position: 6301-6311
# Detected entity: LOCATION, Score: 0.85, Position: 6314-6324
# Detected entity: LOCATION, Score: 0.85, Position: 6327-6337
# Detected entity: LOCATION, Score: 0.85, Position: 6340-6350
# Detected entity: LOCATION, Score: 0.85, Position: 6353-6363
# Detected entity: LOCATION, Score: 0.85, Position: 6366-6376
# Detected entity: LOCATION, Score: 0.85, Position: 6379-6389
# Detected entity: LOCATION, Score: 0.85, Position: 6392-6402
# Detected entity: LOCATION, Score: 0.85, Position: 6405-6415
# Detected entity: LOCATION, Score: 0.85, Position: 6418-6428
# Detected entity: LOCATION, Score: 0.85, Position: 6431-6441
# Detected entity: LOCATION, Score: 0.85, Position: 6444-6454
# Detected entity: LOCATION, Score: 0.85, Position: 6457-6467
# Detected entity: LOCATION, Score: 0.85, Position: 7015-7022
# Detected entity: LOCATION, Score: 0.85, Position: 7977-7984
# Detected entity: LOCATION, Score: 0.85, Position: 10398-10405
#
# Anonymized text:
# Hola, ¿qué tal?  Te llamamos desde Yoigo porque querías hablar con nosotros.  Si quieres información comercial de nuestras ofertas de fibra y móvil, pulsa 1.  Si quieres información comercial de nuestras ofertas de energía, pulsa 2.  Si quieres hacer otra consulta, pulsa 3.  Tu tarifa tiene gigas y llamadas infinitas para hablar y navegar todo lo que quieras.  Tu factura del mes pasado es de 48 ,83 euros.  Recuerda que puedes encontrar toda la información que necesitas en tu área de cliente en nijoigo .com  o en la app.  Dime, ¿en qué puedo ayudarte?  Pues que no puedo yo configurar el Amazon Prime, no sé cómo hacerlo.  De acuerdo, déjame que haga unas comprobaciones en tu televisión.  No te retires, estamos completando las pruebas.  No te retires, estamos completando las pruebas.  Vale, ya está, necesitamos que estés en casa para poder hacer algunas pruebas contigo.  Si estás en casa, espera un momento y enseguida te paso con un agente.  Si no estás en casa, llámanos de nuevo cuando estés para poder ayudarte.  En este momento estamos recibiendo muchas llamadas y tenemos una espera superior a lo habitual.  Si el motivo de tu llamada no es urgente, te agradecemos que consultes la sección de ayuda de nuestra web o que nos llames en otro momento.  Un segundo, no te retires, te paso con un agente.  Buenos días, soy <PERSONA> que puedo ayudarte.  Hola, buenos días.  <PII>, yo he renovado contrato con vosotros y ahora me entra <PERSONA> con anuncio y el Amazon Prime.  El <PERSONA> ya lo tengo configurado en el móvil, que me ayudó un agente, me ayudó a hacerlo, pero ahora yo el Amazon me llama porque el Amazon Prime no lo sé hacer y resulta que me ha dicho que me vaya a mi Yoigo, me he ido y que desde ahí lo podía yo configurar, pero la verdad es que yo no encuentro ni el Amazon Prime ni nada, me encuentro no sé en qué apartado tengo que entrar porque me entro en el Netflix, claro, me salen todas las cosas de <PERSONA>, pero del Amazon no.  Entiendo.  ¿Cuál es tu nombre para saber con quién hablo?  <PII>, <PERSONA>.  <PII>, dime por favor el número de DNI del titular.  746 -033 -27, letra <PERSONA>, 746 -0.  033 -27, letra K.  La dirección del domicilio, ¿cuál es?  Mira, yo lo que pasa es que yo mi domicilio es la <PII>, <PII>, pero tengo una casa en un pueblo de <PII> y ahora estoy aquí, en el pueblo de <PII>.  Y aquí no tengo internet, el internet que tengo es el móvil, que yo, bueno, podía mirar la tele, como no tengo Liga indefinido, puede mirar la tablet y la tele a través del móvil.  Y tú estás intentando instalarlo desde el móvil, entiendo.  Sí, es que lo que tengo es activarlo en el móvil.  Y yo es que soy mayor y ya, no sé, yo estas cosas no la sé.  De acuerdo.  Entonces, ¿la dirección del domicilio, dónde está la instalación?  <PII>, 136, la <PII>, <PII>.  ¿Y el código postal?  No lo sé.  Sé el código postal de aquí donde estoy ahora, pero de allí no lo sé.  Bien, pues entonces, a ver, en principio, aquí no, vale, aquí veo el servicio de <PERSONA>.  Entonces, en principio <PII>, tú dices que has entrado en la aplicación nuestra.  Sí.  Y en la aplicación nuestra, tú entras a lo que es tu perfil, buscas ofertas y promociones.  Sí.  Y no te aparece nada de <PERSONA>.  Bueno, yo es que esto no, ahí no he entrado, yo he entrado en el Netflix.  No, no.  Entra un momento en aplicación.  <PERSONA>, bueno, si ahora me voy para la aplicación, ¿se me corta el móvil?  No.  Mientras no le des, pones el altavoz, pero mientras no le des al, al, ¿cómo se llama?,  al icono rojo, no se corta la llamada.  A ver, si yo estaba dentro de la aplicación cuando te llamaba.  Vale, aquí me sale, o sea televisión, televisión premium, gestionar, <PERSONA> gestionar, pues ya no me sale nada más.  Le doy para atrás, porque claro, yo me he metido a gestionar el Netflix.  No, sí, dale para atrás.  Vale, gestiona tu producto, móvil, tu móvil, el fijo, internet, ocio y televisión, Netflix, móvil e IMAX, nuevos servicios de Yoibo, la Google Drive y todo eso,  ...
